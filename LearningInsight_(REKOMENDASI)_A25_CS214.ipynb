# %% [markdown]
# # **Import Library**

# %%
import pandas as pd

# %% [markdown]
# ## **Collect Initial Data / Load Dataset**

# %%
url='https://drive.google.com/uc?id=1DocxcZuTI5FXQMGRrYUKclmrYzpd9Xmc'
df = pd.read_csv(url, sep=',')

# %% [markdown]
# Dataset yang digunakan dataset setelah dilakukan labeling oleh Model Klasifikasi

# %%
df.head(30)
# Out:
#     user_id  total_point  mean_point  n_kelas  fast  normal  slow  \
# 0      3390            1    0.055556       18     5       7     6
# 1      5774           -1   -0.083333       12     3       7     2
# 2     11836           -1   -0.034483       29     7      16     6
# 3     15166           -5   -0.500000       10     7       1     2
# 4     15507            3    0.103448       29     3      20     6
# 5     17833            4    0.166667       24     5      10     9
# 6     32258            1    0.050000       20     6       7     7
# 7     39414           -4   -0.210526       19     8       7     4
# 8     60558            2    0.125000       16     3       8     5
# 9     64678           -1   -0.047619       21     5      12     4
# 10    71640           -2   -0.080000       25     6      15     4
# 11    77735           -2   -0.166667       12     2      10     0
# 12    82563           -2   -0.105263       19     6       9     4
# ...

# %% [markdown]
# ### **Informasi Dasar**

# %%
# Tinjau jumlah baris kolom dan jenis data dalam dataset dengan info.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             831 non-null    int64
#  1   total_point         831 non-null    int64
#  2   mean_point          831 non-null    float64
#  3   n_kelas             831 non-null    int64
#  4   fast                831 non-null    int64
#  5   normal              831 non-null    int64
#  6   slow                831 non-null    int64
#  7   n_avg_submission    831 non-null    float64
#  8   last_enrolled_at    831 non-null    object
#  9   last_class          831 non-null    object
#  10  learner_type_model  831 non-null    object
# dtypes: float64(2), int64(6), object(3)
# memory usage: 71.5+ KB

# %% [markdown]
# ### **List Rekomendasi tiap Kelas**

# %%
def rekomendasi_dari_kelas(kelas_name: str) -> str:
    k = kelas_name.strip()

    if k == "Belajar Fundamental Aplikasi Android":
        return ("Bagus sekali! Setelah memahami dasar ini, coba perdalam Jetpack Compose dan "
                "pola arsitektur seperti MVVM agar aplikasi yang Anda bangun lebih terstruktur dan rapi.")
    elif k == "Belajar Membuat Aplikasi Android untuk Pemula":
        return ("Kerja bagus! Sekarang buatlah satu aplikasi lengkap kecil, lalu pelajari Navigation, "
                "Room, dan praktikkan rilis sederhana ke Play Store sebagai pengalaman nyata.")
    elif k == "Memulai Pemrograman dengan Kotlin":
        return ("Keren! Lanjutkan dengan mempelajari coroutines untuk asynchronous programming dan "
                "pelajari extension function agar kode Kotlin Anda menjadi lebih elegan dan produktif.")
    elif k == "Memulai Pemrograman dengan Python":
        return ("Mantap! Selanjutnya fokus ke manipulasi data dengan pandas serta membuat skrip otomatisasi "
                "sehari-hari agar kemampuan Anda makin terasa manfaatnya dalam proyek nyata.")
    elif k == "Belajar Dasar Pemrograman Web":
        return ("Bagus sekali! Setelah ini, bikin landing page responsif dan pelajari teknik responsive design "
                "supaya tampilan web Anda nyaman di berbagai perangkat.")
    elif k == "Menjadi Google Cloud Engineer":
        return ("Hebat! Perdalam layanan seperti Compute, Networking, IAM, dan praktik deploy aplikasi nyata "
                "ke GCP untuk memahami bagaimana infrastruktur berjalan dalam produksi.")
    elif k == "Memulai Pemrograman Dengan Swift":
        return ("Luar biasa! Langkah selanjutnya pelajari SwiftUI dan pola arsitektur MVVM agar pengembangan iOS "
                "Anda lebih modern dan mudah dipelihara dalam tim.")
    elif k == "Belajar Membuat Aplikasi Flutter untuk Pemula":
        return ("Bagus! Sekarang coba pelajari state management seperti Provider atau Bloc, lalu bangun aplikasi "
                "multi-halaman sebagai proyek portofolio yang sederhana tapi bermakna.")
    elif k == "Belajar Fundamental Front-End Web Development":
        return ("Keren! Setelah dasar, pelajari framework modern seperti React atau Vue dan praktikkan pembuatan "
                "komponen agar antarmuka yang Anda buat lebih modular dan mudah dikembangkan.")
    elif k == "Menjadi Android Developer Expert":
        return ("Luar biasa ambisinya! Fokus pada arsitektur, testing, performance tuning, dan proses publish "
                "app ke Play Store agar pengalaman Anda menjadi nilai jual nyata.")
    elif k == "Belajar Membuat Aplikasi iOS untuk Pemula":
        return ("Bagus! Lanjuti dengan SwiftUI, pelajari cara konsumsi API, dan buat aplikasi sederhana yang bisa "
                "memproses data dari internet untuk pengalaman penuh.")
    elif k == "Belajar Dasar Visualisasi Data":
        return ("Hebat! Latih membuat dashboard sederhana, fokus pada storytelling visual, dan praktikkan memilih "
                "grafik yang tepat untuk menyampaikan insight kepada audiens.")
    elif k == "Belajar Machine Learning untuk Pemula":
        return ("Mantap! Selanjutnya gunakan scikit-learn untuk membuat pipeline ML sederhana dan kerjakan proyek "
                "klasifikasi atau regresi sebagai latihan end-to-end yang berguna.")
    elif k == "Belajar Fundamental Deep Learning":
        return ("Bagus sekali! Pelajari arsitektur dasar seperti CNN dan RNN, lalu implementasikan contoh sederhana "
                "menggunakan PyTorch atau TensorFlow untuk memperkuat pemahaman.")
    elif k == "Memulai Pemrograman dengan Dart":
        return ("Baik! Gunakan pengetahuan Dart untuk langsung mengembangkan aplikasi Flutter, praktikkan syntax "
                "dan struktur project agar Anda nyaman membangun UI dan logika aplikasi.")
    elif k == "Belajar Fundamental Aplikasi Flutter":
        return ("Hebat! Perdalam lifecycle widget, state management, dan pelajari integrasi REST API agar aplikasi "
                "Anda benar-benar berguna bagi pengguna.")
    elif k == "Menjadi Flutter Developer Expert":
        return ("Ambisi bagus! Fokus pada performa, platform channels untuk native interoperability, testing, dan "
                "deployment ke Play Store dan App Store agar aplikasi siap produksi.")
    elif k == "Belajar Fundamental Aplikasi iOS":
        return ("Keren! Pelajari arsitektur aplikasi iOS, debugging, serta distribusi lewat TestFlight agar rilis "
                "beta Anda dapat umpan balik nyata dari pengguna.")
    elif k == "Menjadi iOS Developer Expert":
        return ("Luar biasa! Perdalam Swift, testing (unit/UI), optimasi performa, dan praktik terbaik untuk "
                "menghasilkan aplikasi iOS berkualitas produksi.")
    elif k == "Belajar Pengembangan Web Intermediate":
        return ("Bagus! Pelajari build tools seperti bundler, optimasi performa, dan teknik SEO dasar agar website "
                "Anda cepat dan mudah ditemukan pengguna.")
    elif k == "Belajar Dasar Cloud dan Gen AI di AWS" or k == "Belajar Dasar dan Gen AI di AWS":
        return ("Menarik! Pelajari layanan AWS untuk AI seperti SageMaker dan Bedrock, lalu praktikkan deploy model "
                "sederhana agar memahami end-to-end workflow.")
    elif k == "Belajar Dasar Pemrograman JavaScript":
        return ("Bagus! Lanjutkan mempelajari DOM manipulation dan konsep asynchronous seperti Promises dan async/await "
                "untuk membuat pengalaman web yang interaktif.")
    elif k == "Belajar Back-End Pemula dengan JavaScript":
        return ("Mantap! Pelajari Node.js dan Express, bangun REST API sederhana, lalu sambungkan ke database untuk "
                "memahami alur backend penuh.")
    elif k == "Architecting on AWS (Membangun Arsitektur Cloud di AWS)":
        return ("Hebat! Fokus pada best practices arsitektur cloud, desain high availability, dan strategi optimasi "
                "biaya agar solusi Anda lebih profesional.")
    elif k == "Belajar Fundamental Back-End dengan JavaScript":
        return ("Bagus! Pelajari database (MongoDB/Postgres), autentikasi, dan error handling agar API Anda semakin "
                "kokoh dan aman saat digunakan.")
    elif k == "Menjadi Back-End Developer Expert dengan JavaScript":
        return ("Ambisius—bagus! Perdalam design patterns, testing, observability, serta microservices agar dapat "
                "menangani beban produksi nyata.")
    elif k == "Simulasi Ujian Associate Cloud Engineer":
        return ("Tenang dan semangat! Gunakan simulasi ini sebagai latihan intensif, fokus pada konsep GCP, dan "
                "ulangi soal-soal untuk meningkatkan kepercayaan diri Anda.")
    elif k == "Meniti Karier sebagai Software Developer":
        return ("Bagus sekali! Susun portofolio proyek, latihan git, dan asah problem solving sambil membuat proyek "
                "kecil yang dapat Anda tunjukkan saat interview.")
    elif k == "Pengenalan ke Logika Pemrograman (Programming Logic 101)":
        return ("Keren! Latih kemampuan menyusun algoritma sederhana dengan flowchart dan implementasikan contoh soal "
                "ke dalam bahasa pemrograman pilihan Anda.")
    elif k == "Belajar Membuat Front-End Web untuk Pemula":
        return ("Bagus! Buat proyek mini seperti website profil pribadi untuk mempraktikkan HTML, CSS, dan JavaScript "
                "sebagai portofolio awal Anda.")
    elif k == "Belajar Dasar Git dengan GitHub":
        return ("Mantap! Terus gunakan git setiap hari, pelajari branching dan pull request, serta ikut kontribusi kecil "
                "ke proyek open source untuk pengalaman kolaboratif.")
    elif k == "Machine Learning Terapan":
        return ("Bagus! Fokus pada pipeline end-to-end: data cleaning, modeling, evaluasi, dan deployment agar hasil Anda "
                "bisa dipakai secara praktis dalam aplikasi nyata.")
    elif k == "Menjadi Google Cloud Architect":
        return ("Hebat! Perdalam desain sistem skala besar, security, dan strategi multi-region agar solusi cloud Anda "
                "handal, aman, dan hemat biaya.")
    elif k == "Belajar Dasar UX Design":
        return ("Bagus! Latih pembuatan wireframe, user testing sederhana, dan pelajari prinsip usability untuk membuat "
                "desain yang benar-benar membantu pengguna.")
    elif k == "Belajar Dasar Google Cloud":
        return ("Keren! Pelajari layanan inti seperti Compute, Storage, dan IAM, lalu deploy aplikasi kecil untuk memahami "
                "alurnya secara praktis.")
    elif k == "Belajar Membuat Aplikasi Back-End untuk Pemula dengan Google Cloud":
        return ("Bagus! Praktikkan deploy API ke Cloud Run atau App Engine, sambungkan ke Cloud SQL, dan monitoring "
                "sederhana agar layanan Anda dapat diandalkan.")
    elif k == "Belajar Pengembangan Aplikasi Android Intermediate":
        return ("Bagus! Fokus pada dependency injection, unit/UI testing, serta optimasi memori agar aplikasi Anda menjadi "
                "lebih stabil dan mudah dipelihara dalam jangka panjang.")
    elif k == "Belajar Dasar-Dasar DevOps":
        return ("Mantap! Pelajari konsep CI/CD, containerization dengan Docker, dan monitoring dasar untuk mempermudah "
                "alur rilis aplikasi Anda.")
    elif k == "Belajar Jaringan Komputer untuk Pemula":
        return ("Keren! Pahami OSI model, subnetting, dan dasar keamanan jaringan, lalu praktikkan konfigurasi jaringan "
                "sederhana untuk pengalaman nyata.")
    elif k == "Belajar Membuat Aplikasi Web dengan React":
        return ("Bagus! Pelajari hooks, component composition, dan state management sederhana agar Anda bisa membuat SPA "
                "yang responsif dan mudah dikembangkan.")
    elif k == "Belajar Fundamental Aplikasi Web dengan React":
        return ("Mantap! Kuatkan dasar React lalu eksplor routing, performance tuning, dan testing komponen untuk "
                "menghasilkan aplikasi web yang solid.")
    elif k == "Menjadi React Web Developer Expert":
        return ("Ambisius dan bagus! Pelajari server-side rendering, testing, dan praktik arsitektur front-end yang "
                "memudahkan tim dalam pengembangan berskala besar.")
    elif k == "Menjadi Linux System Administrator":
        return ("Bagus! Latih administrasi server, scripting bash, manajemen pengguna, dan monitoring logs agar server "
                "Anda stabil dan mudah diawasi.")
    elif k == "Belajar Implementasi CI/CD":
        return ("Keren! Buat pipeline sederhana dengan GitHub Actions atau GitLab CI untuk mengotomatisasi build, test, "
                "dan deploy sehingga workflow Anda lebih cepat dan konsisten.")
    elif k == "Belajar Membangun Arsitektur Microservices":
        return ("Bagus! Pelajari pola komunikasi antar layanan, service discovery, dan observability agar arsitektur "
                "microservices Anda lebih mudah dioperasikan.")
    elif k == "Machine Learning Operations (MLOps)":
        return ("Bagus! Fokus pada reproducibility, model versioning, dan pipeline CI untuk ML agar model yang Anda deploy "
                "dapat dipantau dan diperbarui dengan mudah.")
    elif k == "Belajar Membuat Aplikasi Android dengan Jetpack Compose":
        return ("Hebat! Pelajari prinsip UI deklaratif, state hoisting, dan cara membuat animasi sederhana agar antarmuka "
                "Anda terasa modern dan responsif.")
    elif k == "Belajar Pengembangan Aplikasi Flutter Intermediate":
        return ("Mantap! Pelajari advanced state management, optimasi rendering, dan profiling performa agar aplikasi Flutter "
                "Anda lancar di berbagai perangkat.")
    elif k == "Belajar Analisis Data dengan Python":
        return ("Bagus! Buat notebook end-to-end mulai dari ETL, analisis, sampai visualisasi untuk menghasilkan insight yang "
                "mudah dibaca oleh pemangku kepentingan.")
    elif k == "Belajar Toolset untuk Pengembangan Front-End Web":
        return ("Keren! Siapkan dev environment lengkap, pelajari bundler dan linter, serta biasakan workflow testing agar "
                "pengembangan front-end Anda lebih profesional.")
    elif k == "Belajar Pemrograman Fungsional dengan Haskell":
        return ("Bagus! Pelajari konsep pure functions, monads, dan tipe statis sambil praktik menulis program kecil yang "
                "memanfaatkan gaya fungsional.")
    elif k == "Belajar Penerapan Data Science":
        return ("Keren! Kerjakan studi kasus end-to-end: problem framing, data cleansing, modeling, dan komunikasi hasil "
                "agar solusi Anda berguna bagi pengguna nyata.")
    elif k == "Belajar Dasar Structured Query Language (SQL)":
        return ("Bagus! Latih query kompleks seperti JOIN, GROUP BY, dan window functions pada dataset nyata untuk "
                "mengasah kemampuan analitis Anda.")
    elif k == "Menjadi Node.js Application Developer":
        return ("Mantap! Perkuat pemahaman event loop, clustering, dan monitoring untuk memastikan layanan Node.js Anda "
                "stabil di beban tinggi produksi.")
    elif k == "Belajar Dasar Data Science":
        return ("Bagus! Mulai dari statistik dasar, EDA, dan teknik visualisasi, lalu terapkan pada studi kasus kecil agar "
                "pengetahuan Anda langsung terasa manfaatnya.")
    elif k == "Belajar Pemrograman Prosedural dengan Python":
        return ("Keren! Latih membuat fungsi-fungsi modular dan menulis kode yang mudah diuji sehingga program Anda "
                "lebih terstruktur dan mudah diperbaiki.")
    elif k == "Belajar Dasar AI":
        return ("Bagus! Pahami konsep machine learning dasar, etika AI, dan contoh implementasi sederhana sebelum "
                "melangkah ke topik yang lebih rumit.")
    elif k == "Belajar Penerapan Machine Learning dengan Google Cloud":
        return ("Hebat! Coba deploy model di Vertex AI, pantau performa, dan pahami cost serta lifecycle model di cloud "
                "untuk praktik yang realistis.")
    elif k == "Belajar Penerapan Machine Learning untuk Android":
        return ("Bagus! Pelajari TensorFlow Lite dan integrasikan model ringan ke aplikasi Android agar inferensi dapat "
                "berjalan langsung di perangkat.")
    elif k == "Belajar Strategi Pengembangan Diri":
        return ("Keren! Buat rencana belajar terstruktur dengan milestones mingguan dan evaluasi untuk menjaga konsistensi "
                "dan perkembangan keterampilan jangka panjang Anda.")
    elif k == "Dev Certification for Machine Learning with Tensorflow (DCML) Preparation":
        return ("Mantap! Fokus latihan soal terkait TensorFlow, implementasikan model end-to-end, dan perkuat pemahaman "
                "teknis lewat proyek sederhana.")
    elif k == "Dev Certification for Android (DCA) Preparation":
        return ("Bagus! Latihan soal intensif, review topik inti Android, dan buat beberapa implementasi singkat untuk "
                "mengasah kecepatan dan ketepatan teknis Anda.")
    elif k == "Belajar Fundamental Pemrosesan Data":
        return ("Keren! Perdalam teknik transformasi data, handling missing values, dan rancang pipeline ETL yang dapat "
                "diulang untuk proses data nyata.")
    elif k == "Membangun Sistem Machine Learning":
        return ("Bagus! Rancang pipeline produksi dari data sampai monitoring model, serta rencanakan strategi retraining "
                "yang terukur dan otomatis jika perlu.")
    elif k == "Belajar Back-End Pemula dengan Python":
        return ("Mantap! Pelajari Flask atau Django, buat REST API sederhana, dan hubungkan ke database untuk latihan penuh "
                "backend development.")
    elif k == "Prompt Engineering untuk Software Developer":
        return ("Keren! Eksperimen berbagai prompt untuk debugging, dokumentasi, dan asistensi coding agar AI menjadi alat "
                "yang membantu produktivitas pengembangan Anda.")
    elif k == "Belajar Penerapan Machine Learning untuk Flutter":
        return ("Bagus! Pelajari plugin integrasi TensorFlow Lite di Flutter dan latihan membuat fitur inferensi sederhana "
                "pada aplikasi mobile Anda.")
    elif k == "Belajar Fundamental Back-End dengan Python":
        return ("Baik! Fokus pada desain API yang baik, autentikasi, serta integrasi database agar backend Anda dapat "
                "dipakai aman dan efisien oleh front-end.")
    elif k == "Membangun Proyek Deep Learning Tingkat Mahir":
        return ("Luar biasa! Fokus pada riset arsitektur lanjutan, eksperimentasi hyperparameter, dan dokumentasi eksperimen "
                "agar hasilnya bisa direproduksi dan dipublikasikan.")
    elif k == "Belajar Matematika untuk Data Science":
        return ("Bagus! Perkuat linear algebra, kalkulus dasar, dan probabilitas melalui soal terapan agar Anda lebih siap "
                "mengerti algoritma ML secara matematis.")
    elif k == "AI Praktis untuk Produktivitas":
        return ("Keren! Terapkan model kecil untuk mengotomatisasi tugas harian, buat workflow yang menghemat waktu, dan "
                "ukur dampaknya pada produktivitas Anda.")
    elif k == "Belajar Penggunaan Generative AI":
        return ("Bagus! Praktikkan pembuatan prompt, pelajari aspek safety, dan integrasikan model generatif ke alur kerja "
                "sehari-hari secara bertahap dan terukur.")
    elif k == "Membangun Aplikasi Gen AI dengan Microsoft Azure":
        return ("Menarik! Pelajari layanan Azure AI, integrasikan model generatif ke aplikasi, dan cermati aspek keamanan "
                "serta biaya penggunaan.")
    elif k == "Belajar Penerapan Data Science dengan Microsoft Fabric":
        return ("Bagus! Eksplorasi pipeline data di Fabric, buat laporan interaktif, dan gunakan notebook untuk analisis "
                "yang mudah dibagikan ke tim.")
    elif k == "Belajar Membangun Aplikasi Android Native Bagian I":
        return ("Keren! Setelah dasar ini, lanjutkan ke Bagian II dan praktikkan layout, lifecycle Activity, serta dasar "
                "interaksi antar komponen aplikasi.")
    elif k == "Belajar Mengintegrasikan Android NDK pada Aplikasi/Game Android":
        return ("Menarik! Pelajari JNI dan integrasi kode native untuk mengoptimalkan bagian-bagian performa kritis pada "
                "aplikasi atau game Anda.")
    elif k == "Belajar Membangun Aplikasi Android Native Bagian II":
        return ("Bagus! Fokus pada optimasi dan debugging native layer agar integrasi NDK berjalan mulus tanpa masalah "
                "stabilitas di perangkat nyata.")
    elif k == "Belajar Membangun Aplikasi Android HTML5":
        return ("Baik! Pelajari penggunaan WebView dengan benar, optimasi performa, dan pengalaman hybrid agar pengguna "
                "merasakan aplikasi yang halus.")
    elif k == "Belajar Membuat Aplikasi Android dengan MIT AppInventor 2":
        return ("Cocok untuk prototyping! Setelahnya pindah ke Android Studio untuk belajar struktur project yang lebih "
                "profesional dan kemampuan deploy yang lengkap.")
    elif k == "Belajar Membangun Game Multi Platform":
        return ("Keren! Pelajari engine seperti Unity atau Unreal dan praktikkan export ke beberapa platform untuk memahami "
                "tantangan lintas platform.")
    elif k == "Belajar Membangun Solusi IoT dengan Intel Galileo":
        return ("Bagus! Praktikkan pembacaan sensor, komunikasi MQTT, dan integrasi backend sederhana agar solusi IoT Anda "
                "bisa diuji di lapangan.")
    elif k == "Belajar Membangun Game Android HTML5":
        return ("Baik! Fokus optimasi canvas/WebGL, manajemen memori, dan paketkan dengan wrapper agar game berjalan lancar "
                "di perangkat Android.")
    elif k == "Belajar Membangun Aplikasi Android dengan IBM Bluemix":
        return ("Menarik! Pelajari integrasi cloud services IBM dan cara deploy backend untuk mendukung fitur aplikasi "
                "yang Anda buat.")
    elif k == "Belajar Membangun Game HTML5":
        return ("Keren! Pahami game loop, collision detection, dan packaging untuk web, lalu lakukan playtest dengan "
                "pengguna nyata untuk iterasi desain.")
    elif k == "Belajar Membangun Aplikasi Multi-platform":
        return ("Bagus! Pilih tool seperti Flutter atau React Native dan bangun aplikasi yang bisa berjalan minimal pada dua "
                "platform sebagai eksperimen nyata.")
    elif k == "Belajar Membangun LINE Chatbot":
        return ("Mantap! Pelajari webhook, message handling, dan desain percakapan yang natural agar chatbot memberikan "
                "pengalaman pengguna yang menyenangkan.")
    elif k == "Samsung Galaxy SDK":
        return ("Bagus! Eksplor fitur eksklusif Samsung bila target pengguna Anda banyak memakai perangkat Samsung, "
                "tetapi pertimbangkan kompatibilitas lintas perangkat juga.")
    elif k == "Belajar Membangun Game 2D dan 3D dengan Unity":
        return ("Keren! Perdalam scripting C#, scene management, serta optimasi performa, dan lakukan playtest rutin "
                "untuk menyempurnakan gameplay.")
    elif k == "Belajar Membuat Aplikasi Kognitif dengan IBM Watson":
        return ("Menarik! Pelajari NLU, speech, dan integrasi API Watson untuk membangun fitur kognitif yang membantu "
                "pengguna berinteraksi lebih alami.")
    elif k == "Menjadi Game Developer Expert":
        return ("Ambisius! Fokus pada build portfolio game, physics, AI NPC, dan optimasi performa agar karya Anda "
                "mempesona pemain dan recruiter.")
    elif k == "Kotlin Android Developer Expert":
        return ("Hebat! Perdalam interop Kotlin-Java, coroutines, dan arsitektur aplikasi agar Anda benar-benar mahir "
                "membangun aplikasi Android modern.")
    elif k == "Belajar Membuat Game untuk Pemula":
        return ("Bagus! Mulai dari game sederhana untuk memahami loop dan input handling, lalu tingkatkan kompleksitas "
                "secara bertahap sambil belajar design level.")
    elif k == "Memulai Pemrograman Dengan Java":
        return ("Keren! Pelajari OOP, collections, dan tooling seperti Maven atau Gradle, lalu bangun proyek sederhana "
                "sebagai latihan integrasi konsep.")
    elif k == "Belajar Membuat Game dengan Construct 2":
        return ("Baik! Eksplor event-based logic, desain level, dan buat prototype cepat agar Anda belajar iterasi desain "
                "game dengan cepat.")
    elif k == "Belajar Membuat Aplikasi Kognitif":
        return ("Menarik! Pelajari konsep ML untuk NLP sederhana, integrasi API kognitif, dan uji coba dengan dataset "
                "yang relevan untuk melihat hasil nyata.")
    elif k == "Belajar Membangun Prototype Chatbot Dengan LINE Bot Designer":
        return ("Bagus! Uji prototype dengan pengguna nyata, kumpulkan feedback, dan perbaiki flow percakapan agar lebih "
                "efektif dan natural saat digunakan.")
    elif k == "Membangun Progressive Web Apps":
        return ("Keren! Pelajari service workers, manifest, dan optimasi offline capability agar aplikasi web Anda dapat "
                "berfungsi dan diinstal layaknya aplikasi native.")
    elif k == "Menjadi Azure Cloud Developer":
        return ("Bagus! Perdalam layanan Azure untuk deployment, function, dan storage, serta praktikkan deploy aplikasi "
                "untuk memahami ekosistem Azure secara menyeluruh.")
    elif k == "Pengantar Teknologi Blockchain":
        return ("Menarik! Pelajari smart contract dasar, model konsensus, dan praktik kasus penggunaan realistis sebelum "
                "melangkah ke implementasi lebih kompleks.")
    elif k == "Menjadi Construct 2 Developer Expert":
        return ("Hebat! Perdalam advanced event logic dan optimasi performa sehingga game yang Anda buat berjalan lancar "
                "di berbagai perangkat.")
    elif k == "Menjadi AWS Solutions Architect Associate":
        return ("Bagus! Fokus latihan soal AWS dan praktik mendesain arsitektur untuk berbagai skenario nyata agar siap "
                "dalam ujian dan pekerjaan.")
    elif k == "Menjadi Flutter Developer Expert (2019)":
        return ("Bagus! Perbarui pengetahuan ke fitur Flutter terbaru, pelajari null-safety Dart dan teknik state management "
                "modern untuk aplikasi yang lebih handal.")
    elif k == "Source Code Management untuk Pemula":
        return ("Mantap! Praktikkan branching strategy, code review, dan cara mengelola rilis agar proyek tim Anda lebih "
                "terorganisir dan mudah dipelihara.")
    elif k == "Memulai Pemrograman Dengan C":
        return ("Bagus! Fokus pada pointers, memory management, dan struktur data dasar, karena konsep ini sangat penting "
                "untuk pengembangan sistem.")
    elif k == "Belajar Android Jetpack Pro":
        return ("Keren! Pelajari komponen Jetpack lanjutan seperti WorkManager, Paging, dan Security agar aplikasi Anda "
                "siap menghadapi skenario produksi.")
    elif k == "Belajar Membuat Augmented Reality":
        return ("Menarik! Eksperimen dengan ARCore/ARKit dan pelajari integrasi 3D assets serta antarmuka agar pengalaman "
                "AR terasa natural bagi pengguna.")
    elif k == "Belajar Dasar-Dasar Azure Cloud":
        return ("Bagus! Pelajari VM, storage, dan networking dasar di Azure, lalu coba deploy aplikasi kecil agar paham "
                "alur dan biaya layanan.")
    elif k == "Belajar Membuat Virtual Reality":
        return ("Keren! Perhatikan optimasi rendering dan desain interaksi agar pengalaman VR nyaman dan tidak menyebabkan "
                "motion sickness bagi pengguna.")
    elif k == "Belajar Membangun LINE Front-end Framework (LIFF)":
        return ("Bagus! Integrasikan LIFF dengan backend, perhatikan autentikasi, dan uji alur end-to-end agar pengalaman "
                "pengguna tetap konsisten.")
    elif k == "Belajar Membuat Mixed Reality":
        return ("Menarik! Pelajari spatial mapping, interaksi pengguna, dan optimasi performa agar pengalaman mixed reality "
                "lebih imersif dan stabil.")
    elif k == "Belajar Prinsip Pemrograman SOLID":
        return ("Hebat! Terapkan prinsip SOLID secara bertahap pada proyek nyata dan lakukan refactor untuk meningkatkan "
                "kualitas serta keterbacaan kode.")
    elif k == "Memulai Dasar Pemrograman untuk Menjadi Pengembang Software":
        return ("Bagus! Susun roadmap belajar yang jelas, latih dasar-dasar bahasa pemrograman, dan buat proyek kecil sebagai "
                "bukti kemampuan yang bisa ditunjukkan kepada orang lain.")
    elif k == "Bangkit Application Screening 2021":
        return ("Semangat! Perkuat portfolio dan latih soal-soal coding yang sering muncul agar Anda lebih siap saat "
                "seleksi aplikasi berlangsung.")
    elif k == "Simulasi Ujian TensorFlow Developer Certificate":
        return ("Tetap semangat! Gunakan simulasi ini untuk mengukur kesiapan, kerjakan soal-soal praktik, dan implementasikan "
                "model menggunakan TensorFlow untuk memperkuat pemahaman.")
    elif k == "Belajar Membuat Augmented Reality dengan Lens Studio":
        return ("Keren! Eksperimen asset dan interaksi pengguna, lakukan testing di berbagai perangkat agar efek AR "
                "kerja dengan baik di banyak kondisi.")
    elif k == "Tes Seleksi Offline Training - AI Connect Academy":
        return ("Semangat! Percayalah pada proses belajar Anda, tenangkan diri saat tes, dan gunakan hasilnya untuk "
                "memetakan materi yang perlu diulang.")
    elif k == "Evaluasi Penguasaan Machine Learning":
        return ("Bagus! Gunakan evaluasi ini sebagai alat untuk mengetahui area lemah dan susun rencana belajar yang "
                "terukur berdasarkan hasil tersebut.")
    elif k == "Bangkit General Assessment 2022":
        return ("Tetap bersemangat! Jaga ritme belajar, identifikasi topik yang sering muncul, dan ulangi materi untuk "
                "memperkuat pemahaman jelang assessment.")
    elif k == "Bangkit Machine Learning Assessment 2024 Batch 2":
        return ("Bagus! Fokus ulang pada konsep ML inti dan lakukan banyak latihan soal serta proyek kecil untuk mengasah "
                "ketangkasan teknis Anda.")
    elif k == "Bangkit Android Assessment 2024 Batch 2":
        return ("Mantap! Praktikkan implementasi fitur Android dan cara debugging cepat agar Anda lebih siap menghadapi "
                "soal-soal teknis saat assessment.")
    elif k == "Bangkit 2024 ILT Quiz - Machine Learning":
        return ("Semangat! Gunakan kuis ini sebagai alat ukur, pelajari kembali topik yang belum dikuasai, dan catat "
                "poin-poin penting untuk revisi cepat.")
    elif k == "Bangkit 2024 ILT Quiz - Mobile Development":
        return ("Bagus! Gunakan hasil kuis untuk mengetahui area kelemahan di mobile development, lalu fokus latihan "
                "praktek yang sesuai.")
    elif k == "Bangkit 2024 ILT Quiz - Cloud Computing":
        return ("Mantap! Fokus pada konsep dasar cloud, praktikkan deployment sederhana, dan gunakan quiz sebagai indikator "
                "kesiapan Anda.")
    elif k == "Belajar Membuat Website untuk Menjadi Desainer Website":
        return ("Bagus! Pelajari layout, tipografi, dan aksesibilitas, lalu praktikkan membuat portofolio website yang "
                "menunjukkan kemampuan desain Anda.")
    elif k == "Asah 2025 - Kuis ILT FEBE AI":
        return ("Semangat! Gunakan kuis sebagai sarana konsolidasi pengetahuan, catat kesalahan, dan ulangi topik yang "
                "belum sempurna untuk progres yang nyata.")
    elif k == "SIB 3 ILT Quiz Machine Learning - Front End":
        return ("Bagus! Pertahankan motivasi, gunakan feedback dari kuis untuk memperbaiki bagian yang lemah, dan praktikkan "
                "lagi sampai percaya diri.")
    elif k == "Asah 2025 - Kuis ILT Soft Skill":
        return ("Mantap! Gunakan hasil kuis untuk menyusun rencana pengembangan soft skill dan praktik komunikasi di "
                "situasi nyata agar kemampuan semakin matang.")
    elif k == "BDT 2022 (Tahap 2) Pre-Test Android Developer Dasar":
        return ("Tetap tenang! Pakai pre-test ini sebagai alat ukur kesiapan, lalu ulangi modul yang terasa sulit sampai "
                "lebih paham dan percaya diri.")
    elif k == "BDT 2022 (Tahap 2) Pre-Test Machine Learning Dasar":
        return ("Bagus! Gunakan pre-test untuk memetakan area yang perlu didalami lagi, lalu susun sesi belajar fokus "
                "untuk menutup gap tersebut.")
    elif k == "BDT 2022 (Tahap 2) Pre-Test IT Support":
        return ("Gunakan pre-test ini sebagai pijakan untuk memperkuat dasar-dasar teknis, buat daftar topik yang perlu "
                "diulang, dan praktikkan troubleshooting sederhana.")
    elif k == "BDT 2022 (Tahap 2) Pre-Test Analisis Data":
        return ("Bagus! Identifikasi area statistik atau data wrangling yang perlu diperbaiki, lalu latih dengan dataset "
                "nyata agar keterampilan meningkat.")
    elif k == "Simulasi Ujian Pendidik Level 1 (Google Certified Educator Level 1 - Indonesian)":
        return ("Tetap semangat! Latihan soal yang konsisten dan pembuatan lesson plan akan meningkatkan kesiapan Anda "
                "untuk lulus sertifikasi ini.")
    elif k == "Belajar Membuat Aplikasi Back-End untuk Pemula dengan Cloudeka":
        return ("Bagus! Pelajari deployment dan integrasi database pada platform Cloudeka, praktikkan API sederhana "
                "dan monitoring dasar untuk layanan yang stabil.")
    elif k == "Belajar Dasar DevOps Bagi Insinyur Operasi Pengembang Pemula":
        return ("Mantap! Pelajari CI/CD, container, dan observability, lalu coba terapkan pipeline sederhana pada proyek "
                "kecil untuk pengalaman langsung.")
    elif k == "Belajar Mengembangkan Website dengan HTML dan CSS Bagi Pengembang Web Pemula":
        return ("Bagus! Buat proyek landing page responsif, pelajari best practices accessibility, dan upload ke hosting "
                "atau GitHub Pages sebagai portofolio.")
    elif k == "Memulai Dasar Pemrograman Bagi Pengembang Perangkat Lunak Pemula":
        return ("Keren! Kuasai logika dasar, tipe data, dan control flow; bangun kebiasaan menulis kode rapi sejak awal "
                "karena itu sangat membantu nanti.")
    elif k == "Bangkit General Assessment 2023":
        return ("Gunakan assessment ini untuk memetakan area yang perlu ditingkatkan, atur ulang prioritas belajar, dan "
                "terus konsisten berlatih setiap minggu untuk progres nyata.")
    elif k == "Belajar Dasar Desain UX bagi Desainer UI/UX Pemula":
        return ("Bagus! Kerjakan studi kasus user research, wireframing, dan usability testing agar desain yang Anda hasilkan "
                "benar-benar membantu pengguna.")
    elif k == "Tes Seleksi Asah 2025 – FEBE AI dan REBE AI":
        return ("Semangat! Fokus pada topik inti, percaya pada proses belajarmu, dan gunakan latihan soal untuk memperkuat "
                "kesiapan sebelum tes.")
    elif k == "Simulasi Ujian Pendidik Level 2 (Google Certified Educator Level 2 - Indonesian)":
        return ("Persiapkan diri dengan latihan soal, buat lesson plan matang, dan latih presentasi materi agar lebih "
                "siap saat ujian dan penilaian.")
    elif k == "Simulasi Ujian Penilaian Keterampilan Pelatih (Trainer Skills Assessment - Indonesian)":
        return ("Ingat: proses itu penting. Fokus pada komunikasi efektif, metode pengajaran, dan latihan presentasi agar "
                "keterampilan Anda terlihat saat penilaian.")
    elif k == "Belajar Dasar Manajemen Proyek":
        return ("Bagus! Pelajari metodologi Agile atau Scrum secara praktis, buat rencana proyek kecil, dan praktikkan "
                "perencanaan serta monitoring agar pengalaman Anda nyata.")
    elif k == "Bangkit 2024 ILT Quiz - Soft Skill":
        return ("Gunakan hasil quiz untuk mengasah kemampuan komunikasi dan kerja tim; praktik nyata bersama tim proyek kecil "
                "akan sangat membantu perkembangan skill ini.")
    elif k == "Exam Challenge Campaign Hari Pendidikan":
        return ("Tetap semangat! Jadikan campaign ini sebagai latihan berkala, catat area kelemahan, dan ulangi materi "
                "secara terstruktur untuk peningkatan berkelanjutan.")
    elif k == "Memulai Pemrograman dengan Haskell":
        return ("Bagus! Pelajari tipe aljabar data dan pure functions perlahan-lahan, lakukan latihan kecil agar konsep "
                "fungsional semakin melekat.")
    elif k == "Pre-Test Dicoding Bootcamp":
        return ("Gunakan pre-test ini sebagai baseline; baca hasilnya, kemudian buat rencana belajar yang fokus pada topik "
                "yang belum dikuasai agar persiapan bootcamp lebih matang.")
    elif k == "SIB 5 ILT Quiz Full Stack":
        return ("Semangat! Fokus pada area yang menjadi kekurangan (front-end atau back-end), lalu buat proyek penuh stack "
                "sebagai bukti kompetensi Anda.")
    elif k == "Machine Learning Operations (MLOps) dengan Cloudeka":
        return ("Bagus! Praktikkan CI untuk model, pipeline deployment, dan monitoring di Cloudeka agar model produksi lebih "
                "handal dan mudah dikelola.")
    elif k == "Tes Seleksi BEKUP Create: Upskilling Bootcamp 2025 - Multi-Platform App Developer (Flutter)":
        return ("Tetap percaya diri! Tunjukkan keterampilan praktis Anda pada tes seleksi, dan persiapkan contoh project "
                "yang menonjol dari segi fungsionalitas.")
    elif k == "Asah 2025 - Kuis ILT REBE AI":
        return ("Gunakan kuis ini untuk mengukur pemahaman, catat kesalahan, dan susun materi ulang untuk sesi belajar "
                "yang lebih fokus dan efektif.")
    elif k == "BDT 2024 Web Development Bootcamp ILT Quiz - Front End dan Back End":
        return ("Bagus! Analisa hasil quiz, praktikkan implementasi penuh stack secara terintegrasi, dan perbaiki area "
                "yang masih lemah agar semakin siap menghadapi tugas nyata.")
    elif k == "BDT 2024 Web Development Bootcamp ILT Quiz - Soft Skill":
        return ("Latih komunikasi dan kerjasama tim selama pengerjaan proyek agar soft skill Anda terlihat saat penilaian "
                "dan membantu kelancaran kerja tim.")
    elif k == "Belajar Strategi Perencanaan Karier":
        return ("Luar biasa! Susun roadmap karier dengan milestones 6-12 bulan, portofolio yang jelas, dan langkah-langkah "
                "konkret untuk mencapai tujuan Anda.")
    elif k == "ILT Quiz - Flutter":
        return ("Terus praktik widget dan state management; gunakan kuis ini untuk mengukur progress dan percaya pada "
                "proses belajar Anda yang konsisten.")
    elif k == "ILT Soft Skill Bootcamp":
        return ("Bagus! Latih presentasi, komunikasi, dan kerja tim di proyek nyata; pengalaman praktik akan membuat soft "
                "skill Anda lebih solid.")
    elif k == "Financial Literacy 101" or k == "Introduction to Financial Literacy":
        return ("Keren! Buat anggaran sederhana, pelajari konsep tabungan dan investasi dasar, serta praktikkan pengelolaan "
                "uang dalam kehidupan sehari-hari.")
    elif k == "Belajar Pemrograman Rust untuk Pemula":
        return ("Mantap! Fokus pada konsep ownership, borrowing, dan safe concurrency, lalu praktikkan menulis program kecil "
                "yang memanfaatkan fitur Rust.")
    elif k == "Pengenalan NVIDIA AI Enterprise":
        return ("Menarik! Pelajari ekosistem NVIDIA untuk deployment model besar, optimasi inferensi, dan toolset pendukung "
                "yang relevan untuk produksi.")
    elif k == "Tes Seleksi Pijak in collaboration with IBM SkillsBuild":
        return ("Tetap semangat! Review topik inti, lakukan latihan soal, dan gunakan pre-test sebagai alat ukur kesiapan "
                "sebelum tes seleksi.")
    elif k == "Akselerasi Karier dan Produktivitas dengan Gemini":
        return ("Keren! Pelajari cara mengintegrasikan tools AI ke workflow sehari-hari, atur prioritas, dan ukur peningkatan "
                "produktifitas Anda secara nyata.")
    elif k == "Memulai Pemrograman Dengan C":
        return ("Bagus! Perkuat dasar pointers, memory management, dan struktur data, lalu praktikkan membangun program "
                "kecil yang menunjukkan pemahaman konsep.")
    elif k == "Belajar Dasar Pemrograman untuk Menjadi Pengembang Software":
        return ("Latih kebiasaan menulis kode bersih, dokumentasi, dan testing sederhana agar kemampuan Anda siap digunakan "
                "dalam proyek tim dan kebutuhan profesional.")
    elif k == "Bangkit Application Screening 2021":
        return ("Persiapkan portofolio kuat dan latih soal-soal coding umum; tampilkan proyek yang relevan agar peluang "
                "seleksi meningkat.")
    elif k == "Simulasi Ujian Associate Android Developer":
        return ("Kamu bisa! Gunakan simulasi ini untuk mengasah kecepatan dan ketepatan teknik implementasi fitur Android, "
                "latihan berulang akan meningkatkan performa Anda.")
    elif k.startswith("Bangkit") and "Assessment" in k:
        return ("Gunakan assessment ini sebagai tolok ukur kemajuan; identifikasi kelemahan, susun rencana belajar, dan "
                "latih secara konsisten agar hasil berikutnya lebih baik.")
    elif "Simulasi Ujian" in k or "Simulasi" in k:
        return ("Tetap semangat! Gunakan simulasi sebagai latihan praktik, ulas jawaban yang salah, dan ulangi materi yang "
                "masih terasa kurang untuk meningkatkan kesiapan.")
    elif "Tes Seleksi" in k or "Pre-Test" in k or "Quiz" in k or "Kuis" in k or "ILt Quiz" in k or "ILT Quiz" in k:
        return ("Semangat! Percaya pada persiapanmu, gunakan hasil sebagai bahan evaluasi, dan fokuskan latihan pada "
                "bagian yang menunjukkan kelemahan agar semakin percaya diri.")
    elif k == "Belajar Membangun LINE Front-end Framework (LIFF)":
        return ("Bagus! Praktikkan integrasi LIFF dengan autentikasi dan webhook, uji alur end-to-end agar pengalaman "
                "pengguna menjadi mulus dan aman.")
    elif k == "Belajar Prinsip Pemrograman SOLID":
        return ("Bagus! Terapkan prinsip SOLID secara bertahap pada kode nyata, refactor modul lama, dan tambahkan unit test "
                "untuk memastikan stabilitas desain.")
    elif k == "Belajar Membuat Augmented Reality dengan Lens Studio":
        return ("Lanjutkan eksplorasi asset dan interaksi pengguna, lakukan pengujian di lingkungan nyata agar filter AR "
                "yang dibuat benar-benar menarik dan stabil.")
    elif k == "Evaluasi Penguasaan Machine Learning":
        return ("Gunakan hasil evaluasi untuk membuat peta kemampuan, susun rencana perbaikan yang terukur, dan praktikkan "
                "soal-soal yang relevan untuk menutup gap kemampuan.")
    elif k == "Belajar Membuat Virtual Reality":
        return ("Perhatikan ergonomi, optimasi rendering, dan desain interaksi agar pengalaman VR nyaman; lakukan testing "
                "dengan pengguna untuk menemukan masalah nyata.")
    elif k == "Belajar Mengembangkan Website dengan HTML dan CSS Bagi Pengembang Web Pemula":
        return ("Bagus! Buat landing page responsif, terapkan prinsip aksesibilitas, dan upload ke hosting sederhana untuk "
                "menjadikan portofolio online Anda terlihat profesional.")
    elif k == "Belajar Toolset untuk Pengembangan Front-End Web":
        return ("Siapkan dev environment lengkap, pelajari bundler, linter, test runner, dan gunakan tools tersebut dalam "
                "proyek harian agar workflow Anda lebih efisien.")
    elif k == "Belajar Dasar Structured Query Language (SQL)":
        return ("Latih query analitis pada dataset nyata, pelajari indexing untuk performa, dan praktikkan untuk kebutuhan "
                "laporan dan analisis data nyata.")
    elif k == "Belajar Dasar Jaringan Komputer untuk Pemula" or k == "Belajar Jaringan Komputer untuk Pemula":
        return ("Eksperimen konfigurasi jaringan sederhana, pahami subnetting, dan praktikkan troubleshooting agar konsep "
                "jaringan lebih nyantol di kepala Anda.")
    elif k == "Belajar Dasar-Dasar DevOps":
        return ("Praktikkan pipeline sederhana, containerization, dan monitoring; bangun pengalaman end-to-end agar pemahaman "
                "DevOps Anda terasa kuat dan teruji.")
    elif k == "Belajar Dasar AI" or k == "Belajar Dasar AI":
        return ("Mulailah dengan konsep machine learning sederhana dan etika penggunaan AI, lalu coba implementasi kecil "
                "sebagai bukti konsep yang mudah dipahami.")
    elif k == "Belajar Matematika untuk Data Science":
        return ("Kerjakan soal linear algebra dan probabilitas terapan, karena pemahaman matematika membuat konsep ML lebih "
                "mudah dimengerti dan diaplikasikan.")
    elif k == "Belajar Pemrograman Prosedural dengan Python":
        return ("Latih menulis program prosedural yang modular, gunakan fungsi kecil, dan terapkan testing sederhana untuk "
                "meningkatkan kualitas kode Anda.")
    elif k == "Belajar Dasar Data Science":
        return ("Kerjakan studi kasus eksplorasi data dan visualisasi, pelajari interpretasi statistik, lalu komunikasikan "
                "insight dengan bahasa yang mudah dimengerti.")
    elif k == "Belajar Back-End Pemula dengan Python":
        return ("Buat API sederhana dengan Flask atau Django, hubungkan ke database, dan praktikkan autentikasi untuk memahami "
                "alur back-end nyata.")
    elif k == "Belajar Penerapan Machine Learning dengan Google Cloud":
        return ("Eksperimen deploy model ke Vertex AI, pantau performa, dan pelajari cara mengelola versi model di cloud "
                "agar solusi Anda siap produksi.")
    elif k == "Belajar Penerapan Machine Learning untuk Android":
        return ("Buat model TFLite sederhana, integrasikan ke demo app, dan ukur performa inferensi di perangkat nyata agar "
                "fitur ML terasa berguna.")
    elif k == "Belajar Penerapan Machine Learning untuk Flutter":
        return ("Pelajari plugin integrasi TFLite di Flutter, praktikkan inferensi on-device, dan pastikan performa aplikasi "
                "tetap lancar pada perangkat target.")
    elif k == "Belajar Implementasi CI/CD":
        return ("Automasi build, test, dan deploy secara bertahap; mulai sederhana lalu tambahkan quality gates agar alur rilis "
                "lebih aman dan konsisten.")
    elif k == "Belajar Membangun Arsitektur Microservices":
        return ("Mulai dari desain bounded contexts, tentukan pola komunikasi yang tepat, dan terapkan observability untuk "
                "memudahkan operasi sistem terdistribusi.")
    elif k == "Belajar Membangun Game 2D dan 3D dengan Unity":
        return ("Buat prototype gameplay sederhana, iterasi melalui playtest, dan pelajari optimasi performa agar game Anda "
                "lebih menyenangkan dimainkan.")
    elif k == "Belajar Membuat Game untuk Pemula":
        return ("Mulailah dengan game sederhana, pahami loop, input, dan mekanika dasar; tingkatkan kompleksitas secara bertahap "
                "sambil belajar design level.")
    elif k == "Belajar Membangun Aplikasi Multi-platform":
        return ("Pilih tool yang sesuai seperti Flutter atau React Native, dan fokus membuat satu aplikasi yang berjalan di "
                "lebih dari satu platform sebagai pembelajaran praktis.")
    elif k == "Belajar Membuat Aplikasi Back-End untuk Pemula dengan Google Cloud":
        return ("Deploy service sederhana, hubungkan ke managed DB, dan pelajari monitoring serta backup agar layanan Anda "
                "lebih andal di lingkungan cloud.")
    elif k == "Belajar Dasar Git dengan GitHub":
        return ("Praktikkan branching, pull request, dan code review secara rutin; pengalaman kolaboratif membantu Anda "
                "menjadi pengembang yang siap bekerja di tim.")
    elif k == "Belajar Analisis Data dengan Python":
        return ("Buat notebook end-to-end yang mencakup data cleaning, analysis, dan insight; komunikasikan hasil dengan "
                "visualisasi yang mudah dipahami.")
    elif k == "Belajar Membuat Aplikasi Web dengan React":
        return ("Buat single page application dengan routing, state management, dan konsumsi API; jadikan proyek ini sebagai "
                "portofolio nyata Anda.")
    elif k == "Belajar Fundamental Back-End dengan JavaScript":
        return ("Bangun REST API yang terstruktur, pelajari error handling dan autentikasi, serta gunakan testing untuk "
                "menjamin kualitas layanan Anda.")
    elif k == "Menjadi Node.js Application Developer":
        return ("Perdalam profiling, scaling, dan observability untuk menjalankan layanan Node.js yang handal di lingkungan "
                "produksi dengan beban nyata.")
    elif k == "Belajar Dasar Pemrograman JavaScript":
        return ("Kuasai closures, scope, dan event loop; pemahaman ini akan membuat Anda lebih mudah belajarnya topik-topik "
                "lanjutan JavaScript.")
    elif k == "Belajar Dasar Pemrograman Web":
        return ("Gabungkan HTML, CSS, dan JS dalam proyek nyata, pelajari debugging dasar, dan buat portofolio agar kemampuan "
                "Anda lebih mudah terlihat oleh orang lain.")
    elif k == "Belajar Membuat Front-End Web untuk Pemula":
        return ("Buat proyek portofolio sederhana, upload ke GitHub Pages, dan gunakan feedback untuk memperbaiki tampilan "
                "serta pengalaman pengguna situs Anda.")
    else:
        return ("Rekomendasi umum: kuatkan materi utama dengan praktik langsung, buat proyek kecil sebagai portofolio, "
                "dan gunakan kuis atau simulasi untuk mengukur kemajuan Anda sambil tetap semangat belajar setiap hari.")

df['rekomendasi'] = df['last_class'].apply(rekomendasi_dari_kelas)

# %% [markdown]
# ### **Cek Hasil**

# %%
display(df[['user_id', 'last_class', 'rekomendasi']].head(30))
# Out:
#     user_id                                         last_class  \
# 0      3390                    Kotlin Android Developer Expert
# 1      5774              Belajar Pemrograman Rust untuk Pemula
# 2     11836  Tes Seleksi BEKUP Create: Upskilling Bootcamp ...
# 3     15166              Belajar Machine Learning untuk Pemula
# 4     15507               Belajar Dasar Pemrograman JavaScript
# 5     17833              Belajar Matematika untuk Data Science
# 6     32258                    Belajar Dasar-Dasar Azure Cloud
# 7     39414   Belajar Penerapan Machine Learning untuk Flutter
# 8     60558  DevOps Praktis dengan IBM Cloud (Practical Dev...
# 9     64678              Belajar Pemrograman Rust untuk Pemula
# 10    71640              Belajar Membangun Game Multi Platform
# 11    77735              Belajar Dasar Cloud dan Gen AI di AWS
# 12    82563    Simulasi Ujian TensorFlow Developer Certificate
# 13    96989                     Belajar Dasar Manajemen Proyek
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 831 entries, 0 to 830
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   user_id             831 non-null    int64
#  1   total_point         831 non-null    int64
#  2   mean_point          831 non-null    float64
#  3   n_kelas             831 non-null    int64
#  4   fast                831 non-null    int64
#  5   normal              831 non-null    int64
#  6   slow                831 non-null    int64
#  7   n_avg_submission    831 non-null    float64
#  8   last_enrolled_at    831 non-null    object
#  9   last_class          831 non-null    object
#  10  learner_type_model  831 non-null    object
#  11  rekomendasi         831 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 78.0+ KB

# %%
df.to_csv('rekomendasi_kelas.csv', index=False)
